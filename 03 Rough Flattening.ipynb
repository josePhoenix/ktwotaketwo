# %%
# %pylab inline
import glob
from astropy.io import fits
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyraf import iraf
iraf.kepler(_doprint=0)
# Out:
#
# No Warranty: THE SUBJECT SOFTWARE IS PROVIDED 'AS IS' WITHOUT ANY WARRANTY
# OF ANY KIND, EITHER EXPRESSED, IMPLIED, OR STATUTORY, INCLUDING, BUT NOT
# LIMITED TO, ANY WARRANTY THAT THE SUBJECT SOFTWARE WILL CONFORM TO
# PARTICULAR PURPOSE, OR FREEDOM FROM INFRINGEMENT, ANY WARRANTY THAT THE
# SUBJECT SOFTWARE WILL BE ERROR FREE, OR ANY WARRANTY THAT DOCUMENTATION, IF
# PROVIDED, WILL CONFORM TO THE SUBJECT SOFTWARE. THIS AGREEMENT DOES NOT, IN
# ANY MANNER, CONSTITUTE AN ENDORSEMENT BY GOVERNMENT AGENCY OR ANY PRIOR
# RECIPIENT OF ANY RESULTS, RESULTING DESIGNS, HARDWARE, SOFTWARE PRODUCTS OR
# ANY OTHER APPLICATIONS RESULTING FROM USE OF THE SUBJECT SOFTWARE. FURTHER,
# GOVERNMENT AGENCY DISCLAIMS ALL WARRANTIES AND LIABILITIES REGARDING
# THIRD-PARTY SOFTWARE, IF PRESENT IN THE ORIGINAL SOFTWARE, AND DISTRIBUTES
# IT 'AS IS.'
#
# Waiver and Indemnity: RECIPIENT AGREES TO WAIVE ANY AND ALL CLAIMS AGAINST
# ...

# %% [markdown]
# # Flatten K 3-71
#
# There is perhaps something to be gained from individually examining the timeseries as we flatten them instead of applying the same order polynomial and outlier rejection criteria across all 3 data sets.

# %%
iraf.unlearn('kepflatten')
iraf.kepflatten(
    infile='k371/k371_truncated.fits',
    outfile='k371/k371_flattened.fits',
    datacol='SAP_FLUX',
    errcol='SAP_FLUX_ERR',
    nsig=2.0,
    stepsize=0.2,
    winsize=5.0,
    npoly=2,
    niter=10,
    ranges='0,0',
    plot=True
)
# Out:
# ----------------------------------------------------------------------------
# KEPFLATTEN -- infile=k371/k371_truncated.fits outfile=k371/k371_flattened.fits datacol=SAP_FLUX errcol=SAP_FLUX_ERR nsig=2.0 stepsize=0.2 winsize=5.0 npoly=2 niter=10 ranges=0,0 plot=y clobber=y verbose=y logfile=kepflatten.log
#
# KEPFLATTEN started at: Tue Feb 17 21:37:58 2015
# KEPFLATTEN completed at: Tue Feb 17 21:38:10 2015

# %% [markdown]
# # Flatten J900
#
# Increased winsize from 5.0 days to 7.0 days because it looked like this was overfitting

# %%
iraf.unlearn('kepflatten')
iraf.kepflatten(
    infile='j900/j900_truncated.fits',
    outfile='j900/j900_flattened.fits',
    datacol='SAP_FLUX',
    errcol='SAP_FLUX_ERR',
    nsig=2.0,
    stepsize=0.2,
    winsize=9.0,
    npoly=2,
    niter=10,
    ranges='0,0',
    plot=True
)
# Out:
# ----------------------------------------------------------------------------
# KEPFLATTEN -- infile=j900/j900_truncated.fits outfile=j900/j900_flattened.fits datacol=SAP_FLUX errcol=SAP_FLUX_ERR nsig=2.0 stepsize=0.2 winsize=9.0 npoly=2 niter=10 ranges=0,0 plot=y clobber=y verbose=y logfile=kepflatten.log
#
# KEPFLATTEN started at: Wed Feb 18 00:37:24 2015
# KEPFLATTEN completed at: Wed Feb 18 00:37:39 2015

# %% [markdown]
# # Flatten HoCr 1
#
# Similarly increased winsize to 7 days.

# %%
iraf.unlearn('kepflatten')
iraf.kepflatten(
    infile='hocr1/hocr1_truncated.fits',
    outfile='hocr1/hocr1_flattened.fits',
    datacol='SAP_FLUX',
    errcol='SAP_FLUX_ERR',
    nsig=2.0,
    stepsize=0.2,
    winsize=7.0,
    npoly=2,
    niter=10,
    ranges='0,0',
    plot=True
)
# Out:
# ----------------------------------------------------------------------------
# KEPFLATTEN -- infile=hocr1/hocr1_truncated.fits outfile=hocr1/hocr1_flattened.fits datacol=SAP_FLUX errcol=SAP_FLUX_ERR nsig=2.0 stepsize=0.2 winsize=7.0 npoly=2 niter=10 ranges=0,0 plot=y clobber=y verbose=y logfile=kepflatten.log
#
# KEPFLATTEN started at: Tue Feb 17 21:38:26 2015
# KEPFLATTEN completed at: Tue Feb 17 21:38:41 2015
